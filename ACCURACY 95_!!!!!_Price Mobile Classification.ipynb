# %% [markdown]
# ## IMPORT LIBRARY

# %% [markdown]
# Import the required libraries such as the numpy library, matplotlib, sklearn and others.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
import joblib
import keras
import tensorflow as tf

from sklearn.model_selection import train_test_split, cross_validate, GridSearchCV
from sklearn.preprocessing import RobustScaler, LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.metrics import accuracy_score, roc_curve, auc, precision_score, recall_score, f1_score, confusion_matrix, classification_report, jaccard_score, log_loss, mean_squared_error, confusion_matrix
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import cross_val_score
from keras.utils import np_utils
import keras
from keras.wrappers.scikit_learn import KerasClassifier
from keras.regularizers import l2
from keras.optimizers import SGD

# %% [markdown]
# ## IMPORT DATASET

# %% [markdown]
# Calling the dataset in csv format and stored in the "df_train" variable then displaying the top 5 data using the .head() syntax

# %%
df_train = pd.read_csv("/content/drive/MyDrive/Kaggle/train_Mobile Price Classification.csv")
df_train.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        1             1     0            2
# 3        1             0     0            2
# 4        1             1     0            1
#
# [5 rows x 21 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# In the early stages of EDA, the first thing to do is look at the information from the dataset using the info() syntax. By using this syntax we can see the amount of data in each column and the data type. Because this dataset aims to predict whether the company will go bankrupt or not, the data needed is data in int and float format. After that other information can be seen using the syntax describe(). With this syntax we can see the average value and standard deviation of the dataset.

# %%
df_train.info()
df_train.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
#  18  touch_screen   2000 non-null   int64
#  19  wifi           2000 non-null   int64
#  20  price_range    2000 non-null   int64
# dtypes: float64(2), int64(19)
# memory usage: 328.2 KB
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# min       0.000000     2.000000     0.100000    80.000000     1.000000  ...
# 25%       0.000000    16.000000     0.200000   109.000000     3.000000  ...
# 50%       1.000000    32.000000     0.500000   141.000000     4.000000  ...
# 75%       1.000000    48.000000     0.800000   170.000000     7.000000  ...
# max       1.000000    64.000000     1.000000   200.000000     8.000000  ...
#
#          px_height     px_width          ram         sc_h         sc_w  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean    645.108000  1251.515500  2124.213000    12.306500     5.767000
# std     443.780811   432.199447  1084.732044     4.213245     4.356398
# min       0.000000   500.000000   256.000000     5.000000     0.000000
# 25%     282.750000   874.750000  1207.500000     9.000000     2.000000
# 50%     564.000000  1247.000000  2146.500000    12.000000     5.000000
# 75%     947.250000  1633.000000  3064.500000    16.000000     9.000000
# max    1960.000000  1998.000000  3998.000000    19.000000    18.000000
#
#          talk_time      three_g  touch_screen         wifi  price_range
# count  2000.000000  2000.000000   2000.000000  2000.000000  2000.000000
# mean     11.011000     0.761500      0.503000     0.507000     1.500000
# std       5.463955     0.426273      0.500116     0.500076     1.118314
# min       2.000000     0.000000      0.000000     0.000000     0.000000
# 25%       6.000000     1.000000      0.000000     0.000000     0.750000
# 50%      11.000000     1.000000      1.000000     1.000000     1.500000
# 75%      16.000000     1.000000      1.000000     1.000000     2.250000
# max      20.000000     1.000000      1.000000     1.000000     3.000000
#
# [8 rows x 21 columns]

# %% [markdown]
# Karena dataset ini termasuk pada klasifikasi maka balancing data target harus diperhatikan. Cara melihatnya dapat menggunakan syntax value_counts() untuk mengetahui jumlah data pada setiap kolom.

# %%
df_train['price_range'].value_counts()
# Out:
# 1    500
# 2    500
# 3    500
# 0    500
# Name: price_range, dtype: int64

# %% [markdown]
# This syntax aims to check whether in this dataset there is null data or duplicate data. If there is then the data must be deleted or replaced with the data that should be. Because in this dataset there are no null data and duplicated data, the data drop or fill data stage is not needed.

# %%
print("=========== Sum null of dataset================== ")
print(df_train.isnull().sum())
print("=========== Sum Duplicate of dataset================== ")
df_train[df_train.duplicated()]
# Out:
# =========== Sum null of dataset==================
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64
# =========== Sum Duplicate of dataset==================
# Empty DataFrame
# Columns: [battery_power, blue, clock_speed, dual_sim, fc, four_g, int_memory, m_dep, mobile_wt, n_cores, pc, px_height, px_width, ram, sc_h, sc_w, talk_time, three_g, touch_screen, wifi, price_range]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# After that look at the correlation between the data. In the image below, what must be seen is the correlation between the price_range data and other data. If you look at the picture, the highest correlation is found in RAM data, which is 0.92, while the other data is quite bad.

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(df_train.corr(), annot=True)
plt.show()

# %% [markdown]
# Then look at the distribution of data in the dataset using boxplot plots. By using a boxplot you can also check whether the data has outliers or not. If there is then the outlier must be removed. And from this plot, the "fc" and "px_height" data columns have outliers so that the outliers for these two columns must be removed in order to eliminate noise when modeling.

# %%
for column in df_train:
    plt.figure()
    df_train.boxplot([column])
# Out:
# <ipython-input-10-d2ecf9fdaf3f>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()

# %% [markdown]
# Dibawah ini merupakan syntax untuk menghapus outlier dengan menggunakan selisih antara quantile 3 dan quantile 1.

# %%
num_var = ['fc', 'px_height']
for i in num_var:
    Q1 = df_train[i].quantile(0.25)
    Q3 = df_train[i].quantile(0.75)
    IQR = Q3 - Q1
    df_train[i] = np.where(df_train[i]>(Q3+1.5*IQR),(Q3+1.5*IQR),df_train[i])
    df_train[i] = np.where(df_train[i]<(Q1-1.5*IQR),(Q1-1.5*IQR),df_train[i])

# %% [markdown]
# Mengecek kembali apakah data tersebut outliernya sudah terhapus atau belum.

# %%
for column in df_train:
    plt.figure()
    df_train.boxplot([column])
# Out:
# <ipython-input-12-d2ecf9fdaf3f>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()

# %% [markdown]
# Setelah itu melihat juga sebaran data menggunakan ploting histogram.

# %%
df_train.hist(bins=50, figsize=(20,15))
plt.show()

# %% [markdown]
# After the information from the dataset is sufficient, the next step is to separate the data between feature data and target data. The reason is because the next stage is data scaling and data scaling is only done on feature data.

# %%
X = df_train.drop('price_range', axis=1).reset_index(drop=True)
y = df_train['price_range'].reset_index(drop=True)

# %% [markdown]
# At this stage, scaling the data using a standard scaler. The purpose of the standard scaler is to make the mean value 0 and the variance 1.

# %%
tf = StandardScaler().fit_transform(X)
scaledf = pd.DataFrame(tf, columns=X.columns)
scaledf['price_range'] = y
scaledf
# Out:
#       battery_power      blue  clock_speed  dual_sim        fc    four_g  \
# 0         -0.902597 -0.990050     0.830779 -1.019184 -0.766948 -1.043966
# 1         -0.495139  1.010051    -1.253064  0.981177 -0.999780  0.957886
# 2         -1.537686  1.010051    -1.253064  0.981177 -0.534116  0.957886
# 3         -1.419319  1.010051     1.198517 -1.019184 -0.999780 -1.043966
# 4          1.325906  1.010051    -0.395011 -1.019184  2.027033  0.957886
# ...             ...       ...          ...       ...       ...       ...
# 1995      -1.011860  1.010051    -1.253064  0.981177 -0.999780  0.957886
# 1996       1.653694  1.010051     1.321096  0.981177 -0.999780 -1.043966
# 1997       1.530773 -0.990050    -0.762748  0.981177 -0.766948  0.957886
# 1998       0.622527 -0.990050    -0.762748 -1.019184 -0.068453  0.957886
# 1999      -1.658331  1.010051     0.585621  0.981177  0.164379  0.957886
#
#       int_memory     m_dep  mobile_wt   n_cores  ...  px_height  px_width  \
# 0      -1.380644  0.340740   1.349249 -1.101971  ...  -1.409023 -1.146784
# 1       1.155024  0.687548  -0.120059 -0.664768  ...   0.585842  1.704465
# 2       0.493546  1.381165   0.134244  0.209639  ...   1.392805  1.074968
# 3      -1.215274  1.034357  -0.261339  0.646842  ...   1.286863  1.236971
# 4       0.658915  0.340740   0.021220 -1.101971  ...   1.268830 -0.091452
# ...          ...       ...        ...       ...  ...        ...       ...
# 1995   -1.656260  1.034357  -0.967737  0.646842  ...   1.300387  1.477661
# 1996    0.383299 -1.046495   1.320993 -0.227564  ...   0.608383  1.651235
# 1997    0.217930  0.687548  -0.911225  1.521249  ...   0.502441  0.880565
# 1998    0.769162 -1.393304   0.134244  0.209639  ...  -0.696732 -1.345816
# 1999    0.714039  1.381165   0.784130  0.646842  ...  -0.365382 -1.151413
#
#            ram      sc_h      sc_w  talk_time   three_g  touch_screen  \
# 0     0.391703 -0.784983  0.283103   1.462493 -1.786861     -1.006018
# 1     0.467317  1.114266 -0.635317  -0.734267  0.559641      0.994018
# 2     0.441498 -0.310171 -0.864922  -0.368140  0.559641      0.994018
# 3     0.594569  0.876859  0.512708  -0.002014  0.559641     -1.006018
# 4    -0.657666 -1.022389 -0.864922   0.730240  0.559641      0.994018
# ...        ...       ...       ...        ...       ...           ...
# 1995 -1.342799  0.164641 -0.405712   1.462493  0.559641      0.994018
# 1996 -0.085031 -0.310171  0.971917   0.913303  0.559641      0.994018
# 1997  0.860139 -0.784983 -1.094526  -1.100394  0.559641      0.994018
# 1998 -1.157454  1.351672  0.971917   1.462493  0.559641      0.994018
# 1999  1.655004  1.589078 -0.405712  -1.649584  0.559641      0.994018
#
#           wifi  price_range
# 0     0.986097            1
# 1    -1.014099            2
# 2    -1.014099            2
# 3    -1.014099            2
# 4    -1.014099            1
# ...        ...          ...
# 1995 -1.014099            0
# 1996  0.986097            2
# 1997 -1.014099            3
# 1998  0.986097            0
# 1999  0.986097            3
#
# [2000 rows x 21 columns]

# %% [markdown]
# Then the data that has been scaled will be divided into 4 parts, namely x_test, x_train, y_train, and y_test. The division of the data is 80% train data and 20% test data.

# %%
xx = scaledf.drop('price_range', axis=1)
yy = scaledf['price_range']
X_train, X_test, y_train, y_test = train_test_split(xx, yy, test_size=0.2, random_state=42)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (1600, 20) (1600,) (400, 20) (400,)

# %% [markdown]
# Create a validation variable by means of reverse data.

# %%
x_val = X_train[-400:]
y_val = y_train[-400:]

# %% [markdown]
# Create a model using Sequential. This model consists of 3 layers, 1 input layer uses 20 nodes because there are 20 feature columns and uses Relu activation with the aim of making negative values ​​become 0 and data above 0 will remain. Next, 1 hidden layer uses 2 nodes and activates Relu. After that, 1 layer output layer uses 4 nodes, the reason is that this dataset targets 4 classes, namely 0,1,2,3, so this dataset includes a multiclass classification. For that reason, the activation function used is softmax.

# %%
model = keras.Sequential()
model.add(Dense(units = 20, activation='relu', input_dim= 20)) #input layer
model.add(Dense(units = 2, activation='relu')) #hidden layer
model.add(Dense(units = 4, activation='softmax')) # output layer

# %% [markdown]
# Here is a summery model that has been made

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 20)                420
#
#  dense_1 (Dense)             (None, 2)                 42
#
#  dense_2 (Dense)             (None, 4)                 12
#
# =================================================================
# Total params: 474
# Trainable params: 474
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# The next stage is compiling the model. The optimizer used is SGD with a learning rate of 0.001. Then the loss used is sparse categorical crossentropy, this loss was chosen because for the multiclass loss classification case used is sparse categorical crossentropy. And for the metrics use accuracy.

# %%
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

# %% [markdown]
# Then the model will be fitted with batch size 16 and epoch 200. And obtained loss 0.3735, accuracy 0.9050, val loss 0.3740, and val accuracy 0.9050

# %%
history = model.fit(
    X_train,
    y_train,
    batch_size=16,
    epochs=500,
    validation_data=(x_val, y_val),
)
# Out:
# Epoch 1/500
# 100/100 [==============================] - 1s 4ms/step - loss: 1.5020 - accuracy: 0.2481 - val_loss: 1.4773 - val_accuracy: 0.2325
# Epoch 2/500
# 100/100 [==============================] - 0s 3ms/step - loss: 1.4666 - accuracy: 0.2556 - val_loss: 1.4485 - val_accuracy: 0.2450
# Epoch 3/500
# 100/100 [==============================] - 0s 3ms/step - loss: 1.4419 - accuracy: 0.2575 - val_loss: 1.4278 - val_accuracy: 0.2625
# Epoch 4/500
# 100/100 [==============================] - 0s 2ms/step - loss: 1.4246 - accuracy: 0.2625 - val_loss: 1.4137 - val_accuracy: 0.2575
# Epoch 5/500
# 100/100 [==============================] - 0s 3ms/step - loss: 1.4119 - accuracy: 0.2694 - val_loss: 1.4032 - val_accuracy: 0.2775
# Epoch 6/500
# 100/100 [==============================] - 0s 2ms/step - loss: 1.4024 - accuracy: 0.2788 - val_loss: 1.3956 - val_accuracy: 0.2825
# Epoch 7/500
# 100/100 [==============================] - 0s 3ms/step - loss: 1.3953 - accuracy: 0.2781 - val_loss: 1.3898 - val_accuracy: 0.2875
# Epoch 8/500
# 100/100 [==============================] - 0s 2ms/step - loss: 1.3898 - accuracy: 0.2825 - val_loss: 1.3853 - val_accuracy: 0.2925
# Epoch 9/500
# 100/100 [==============================] - 0s 2ms/step - loss: 1.3851 - accuracy: 0.2825 - val_loss: 1.3814 - val_accuracy: 0.2850
# Epoch 10/500
# 100/100 [==============================] - 0s 3ms/step - loss: 1.3810 - accuracy: 0.2837 - val_loss: 1.3782 - val_accuracy: 0.2900
# Epoch 11/500
# 100/100 [==============================] - 0s 3ms/step - loss: 1.3774 - accuracy: 0.2906 - val_loss: 1.3754 - val_accuracy: 0.2975
# Epoch 12/500
# 100/100 [==============================] - 0s 3ms/step - loss: 1.3742 - accuracy: 0.2937 - val_loss: 1.3728 - val_accuracy: 0.3050
# Epoch 13/500
# 100/100 [==============================] - 0s 2ms/step - loss: 1.3712 - accuracy: 0.2962 - val_loss: 1.3703 - val_accuracy: 0.3075
# Epoch 14/500
# 100/100 [==============================] - 0s 2ms/step - loss: 1.3684 - accuracy: 0.3000 - val_loss: 1.3679 - val_accuracy: 0.3125
# Epoch 15/500
# 100/100 [==============================] - 0s 2ms/step - loss: 1.3657 - accuracy: 0.2969 - val_loss: 1.3657 - val_accuracy: 0.3125
# Epoch 16/500
# 100/100 [==============================] - 0s 3ms/step - loss: 1.3632 - accuracy: 0.3006 - val_loss: 1.3635 - val_accuracy: 0.3100
# Epoch 17/500
# 100/100 [==============================] - 0s 3ms/step - loss: 1.3607 - accuracy: 0.2981 - val_loss: 1.3615 - val_accuracy: 0.3175
# Epoch 18/500
# 100/100 [==============================] - 0s 2ms/step - loss: 1.3583 - accuracy: 0.3000 - val_loss: 1.3594 - val_accuracy: 0.3150
# Epoch 19/500
# 100/100 [==============================] - 0s 2ms/step - loss: 1.3559 - accuracy: 0.3000 - val_loss: 1.3573 - val_accuracy: 0.3175
# Epoch 20/500
# 100/100 [==============================] - 0s 3ms/step - loss: 1.3536 - accuracy: 0.3050 - val_loss: 1.3552 - val_accuracy: 0.3250
# Epoch 21/500
# 100/100 [==============================] - 0s 2ms/step - loss: 1.3511 - accuracy: 0.3063 - val_loss: 1.3530 - val_accuracy: 0.3275
# Epoch 22/500
# 100/100 [==============================] - 0s 2ms/step - loss: 1.3486 - accuracy: 0.3050 - val_loss: 1.3508 - val_accuracy: 0.3250
# Epoch 23/500
# 100/100 [==============================] - 0s 3ms/step - loss: 1.3460 - accuracy: 0.3081 - val_loss: 1.3485 - val_accuracy: 0.3325
# Epoch 24/500
# 100/100 [==============================] - 0s 2ms/step - loss: 1.3434 - accuracy: 0.3125 - val_loss: 1.3462 - val_accuracy: 0.3375
# Epoch 25/500
# 100/100 [==============================] - 0s 3ms/step - loss: 1.3408 - accuracy: 0.3144 - val_loss: 1.3438 - val_accuracy: 0.3325
# Epoch 26/500
# 100/100 [==============================] - 0s 3ms/step - loss: 1.3380 - accuracy: 0.3119 - val_loss: 1.3413 - val_accuracy: 0.3150
# Epoch 27/500
# 100/100 [==============================] - 0s 2ms/step - loss: 1.3351 - accuracy: 0.3137 - val_loss: 1.3386 - val_accuracy: 0.3200
# Epoch 28/500
# 100/100 [==============================] - 0s 2ms/step - loss: 1.3321 - accuracy: 0.3181 - val_loss: 1.3359 - val_accuracy: 0.3100
# Epoch 29/500
# 100/100 [==============================] - 0s 3ms/step - loss: 1.3290 - accuracy: 0.3137 - val_loss: 1.3330 - val_accuracy: 0.3225
# Epoch 30/500
# 100/100 [==============================] - 0s 2ms/step - loss: 1.3258 - accuracy: 0.3169 - val_loss: 1.3301 - val_accuracy: 0.3200
# Epoch 31/500
# 100/100 [==============================] - 0s 3ms/step - loss: 1.3224 - accuracy: 0.3144 - val_loss: 1.3272 - val_accuracy: 0.3200
# Epoch 32/500
# 100/100 [==============================] - 0s 2ms/step - loss: 1.3190 - accuracy: 0.3181 - val_loss: 1.3240 - val_accuracy: 0.3225
# Epoch 33/500
# 100/100 [==============================] - 0s 2ms/step - loss: 1.3155 - accuracy: 0.3187 - val_loss: 1.3208 - val_accuracy: 0.3225
# Epoch 34/500
# 100/100 [==============================] - 0s 2ms/step - loss: 1.3118 - accuracy: 0.3169 - val_loss: 1.3175 - val_accuracy: 0.3225
# Epoch 35/500
# 100/100 [==============================] - 0s 3ms/step - loss: 1.3080 - accuracy: 0.3162 - val_loss: 1.3141 - val_accuracy: 0.3250
# Epoch 36/500
# 100/100 [==============================] - 0s 2ms/step - loss: 1.3040 - accuracy: 0.3169 - val_loss: 1.3104 - val_accuracy: 0.3225
# Epoch 37/500
# 100/100 [==============================] - 0s 2ms/step - loss: 1.2998 - accuracy: 0.3181 - val_loss: 1.3067 - val_accuracy: 0.3275
# Epoch 38/500
# 100/100 [==============================] - 0s 3ms/step - loss: 1.2956 - accuracy: 0.3244 - val_loss: 1.3028 - val_accuracy: 0.3325
# Epoch 39/500
# 100/100 [==============================] - 0s 2ms/step - loss: 1.2911 - accuracy: 0.3256 - val_loss: 1.2986 - val_accuracy: 0.3350
# Epoch 40/500
# 100/100 [==============================] - 0s 2ms/step - loss: 1.2865 - accuracy: 0.3256 - val_loss: 1.2942 - val_accuracy: 0.3325
# Epoch 41/500
# 100/100 [==============================] - 0s 2ms/step - loss: 1.2817 - accuracy: 0.3294 - val_loss: 1.2897 - val_accuracy: 0.3400
# Epoch 42/500
# 100/100 [==============================] - 0s 2ms/step - loss: 1.
500
# 100/100 [==============================] - 0s 2ms/step - loss: 1.0679 - accuracy: 0.5369 - val_loss: 1.0862 - val_accuracy: 0.5425
# Epoch 72/500
# 100/100 [==============================] - 0s 3ms/step - loss: 1.0593 - accuracy: 0.5394 - val_loss: 1.0777 - val_accuracy: 0.5425
# Epoch 73/500
# 100/100 [==============================] - 0s 2ms/step - loss: 1.0506 - accuracy: 0.5400 - val_loss: 1.0693 - val_accuracy: 0.5425
# Epoch 74/500
# 100/100 [==============================] - 0s 2ms/step - loss: 1.0420 - accuracy: 0.5444 - val_loss: 1.0608 - val_accuracy: 0.5400
# Epoch 75/500
# 100/100 [==============================] - 0s 2ms/step - loss: 1.0333 - accuracy: 0.5444 - val_loss: 1.0523 - val_accuracy: 0.5400
# Epoch 76/500
# 100/100 [==============================] - 0s 2ms/step - loss: 1.0246 - accuracy: 0.5437 - val_loss: 1.0437 - val_accuracy: 0.5425
# Epoch 77/500
# 100/100 [==============================] - 0s 2ms/step - loss: 1.0160 - accuracy: 0.5462 - val_loss: 1.0352 - val_accuracy: 0.5450
# Epoch 78/500
# 100/100 [==============================] - 0s 2ms/step - loss: 1.0073 - accuracy: 0.5506 - val_loss: 1.0266 - val_accuracy: 0.5500
# Epoch 79/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.9985 - accuracy: 0.5556 - val_loss: 1.0178 - val_accuracy: 0.5500
# Epoch 80/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.9898 - accuracy: 0.5562 - val_loss: 1.0090 - val_accuracy: 0.5450
# Epoch 81/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.9810 - accuracy: 0.5550 - val_loss: 1.0003 - val_accuracy: 0.5500
# Epoch 82/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.9722 - accuracy: 0.5594 - val_loss: 0.9915 - val_accuracy: 0.5525
# Epoch 83/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.9635 - accuracy: 0.5644 - val_loss: 0.9827 - val_accuracy: 0.5575
# Epoch 84/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.9547 - accuracy: 0.5663 - val_loss: 0.9739 - val_accuracy: 0.5625
# Epoch 85/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.9460 - accuracy: 0.5725 - val_loss: 0.9652 - val_accuracy: 0.5625
# Epoch 86/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.9374 - accuracy: 0.5756 - val_loss: 0.9565 - val_accuracy: 0.5675
# Epoch 87/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.9287 - accuracy: 0.5763 - val_loss: 0.9478 - val_accuracy: 0.5700
# Epoch 88/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.9201 - accuracy: 0.5813 - val_loss: 0.9391 - val_accuracy: 0.5875
# Epoch 89/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.9115 - accuracy: 0.5894 - val_loss: 0.9305 - val_accuracy: 0.5900
# Epoch 90/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.9030 - accuracy: 0.5919 - val_loss: 0.9219 - val_accuracy: 0.5925
# Epoch 91/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.8945 - accuracy: 0.5969 - val_loss: 0.9135 - val_accuracy: 0.6025
# Epoch 92/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.8861 - accuracy: 0.6006 - val_loss: 0.9050 - val_accuracy: 0.6075
# Epoch 93/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.8777 - accuracy: 0.6081 - val_loss: 0.8966 - val_accuracy: 0.6175
# Epoch 94/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.8694 - accuracy: 0.6131 - val_loss: 0.8882 - val_accuracy: 0.6225
# Epoch 95/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.8610 - accuracy: 0.6206 - val_loss: 0.8797 - val_accuracy: 0.6275
# Epoch 96/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.8527 - accuracy: 0.6263 - val_loss: 0.8713 - val_accuracy: 0.6300
# Epoch 97/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.8445 - accuracy: 0.6331 - val_loss: 0.8630 - val_accuracy: 0.6350
# Epoch 98/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.8363 - accuracy: 0.6400 - val_loss: 0.8546 - val_accuracy: 0.6500
# Epoch 99/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.8282 - accuracy: 0.6544 - val_loss: 0.8464 - val_accuracy: 0.6575
# Epoch 100/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.8202 - accuracy: 0.6556 - val_loss: 0.8382 - val_accuracy: 0.6650
# Epoch 101/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.8122 - accuracy: 0.6687 - val_loss: 0.8302 - val_accuracy: 0.6750
# Epoch 102/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.8043 - accuracy: 0.6750 - val_loss: 0.8222 - val_accuracy: 0.6775
# Epoch 103/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.7966 - accuracy: 0.6812 - val_loss: 0.8143 - val_accuracy: 0.6775
# Epoch 104/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.7889 - accuracy: 0.6850 - val_loss: 0.8066 - val_accuracy: 0.6875
# Epoch 105/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.7813 - accuracy: 0.6925 - val_loss: 0.7989 - val_accuracy: 0.6875
# Epoch 106/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.7738 - accuracy: 0.7013 - val_loss: 0.7913 - val_accuracy: 0.6925
# Epoch 107/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.7665 - accuracy: 0.7056 - val_loss: 0.7838 - val_accuracy: 0.6950
# Epoch 108/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.7593 - accuracy: 0.7106 - val_loss: 0.7765 - val_accuracy: 0.7025
# Epoch 109/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.7521 - accuracy: 0.7131 - val_loss: 0.7693 - val_accuracy: 0.7100
# Epoch 110/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.7451 - accuracy: 0.7188 - val_loss: 0.7621 - val_accuracy: 0.7125
# Epoch 111/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.7382 - accuracy: 0.7225 - val_loss: 0.7550 - val_accuracy: 0.7200
# Epoch 112/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.7314 - accuracy: 0.7262 - val_loss: 0.7481 - val_accuracy: 0.7175
# Epoch 113/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.7247 - accuracy: 0.7325 - val_loss: 0.7412 - val_accuracy: 0.7200
# Epoch 114/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.7180 - accuracy: 0.7362 - val_loss: 0.7346 - val_accuracy: 0.7200
# Epoch 115/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.7115 - accuracy: 0.7419 - val_loss: 0.7279 - val_accuracy: 0.7250
# Epoch 116/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.7051 - accuracy: 0.7481 - val_loss: 0.7214 - val_accuracy: 0.7300
# Epoch 117/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6987 - accuracy: 0.7513 - val_loss: 0.7150 - val_accuracy: 0.7325
# Epoch 118/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6925 - accuracy: 0.7531 - val_loss: 0.7087 - val_accuracy: 0.7350
# Epoch 119/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6864 - accuracy: 0.7556 - val_loss: 0.7026 - val_accuracy: 0.7375
# Epoch 120/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6804 - accuracy: 0.7581 - val_loss: 0.6964 - val_accuracy: 0.7375
# Epoch 121/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6744 - accuracy: 0.7594 - val_loss: 0.6904 - val_accuracy: 0.7450
# Epoch 122/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6686 - accuracy: 0.7600 - val_loss: 0.6845 - val_accuracy: 0.7475
# Epoch 123/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6628 - accuracy: 0.7638 - val_loss: 0.6787 - val_accuracy: 0.7475
# Epoch 124/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6571 - accuracy: 0.7675 - val_loss: 0.6730 - val_accuracy: 0.7525
# Epoch 125/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6515 - accuracy: 0.7700 - val_loss: 0.6673 - val_accuracy: 0.7525
# Epoch 126/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6460 - accuracy: 0.7731 - val_loss: 0.6618 - val_accuracy: 0.7575
# Epoch 127/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6406 - accuracy: 0.7763 - val_loss: 0.6563 - val_accuracy: 0.7575
# Epoch 128/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6352 - accuracy: 0.7769 - val_loss: 0.6509 - val_accuracy: 0.7600
# Epoch 129/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6300 - accuracy: 0.7812 - val_loss: 0.6456 - val_accuracy: 0.7625
# Epoch 130/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6248 - accuracy: 0.7825 - val_loss: 0.6404 - val_accuracy: 0.7700
# Epoch 131/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6197 - accuracy: 0.7862 - val_loss: 0.6353 - val_accuracy: 0.7700
# Epoch 132/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6147 - accuracy: 0.7856 - val_loss: 0.6302 - val_accuracy: 0.7700
# Epoch 133/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6098 - accuracy: 0.7900 - val_loss: 0.6253 - val_accuracy: 0.7700
# Epoch 134/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6049 - accuracy: 0.7906 - val_loss: 0.6203 - val_accuracy: 0.7725
# Epoch 135/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6001 - accuracy: 0
500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3613 - accuracy: 0.8806 - val_loss: 0.3757 - val_accuracy: 0.8825
# Epoch 212/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3592 - accuracy: 0.8813 - val_loss: 0.3737 - val_accuracy: 0.8825
# Epoch 213/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3572 - accuracy: 0.8806 - val_loss: 0.3717 - val_accuracy: 0.8825
# Epoch 214/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3552 - accuracy: 0.8813 - val_loss: 0.3696 - val_accuracy: 0.8825
# Epoch 215/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.3532 - accuracy: 0.8825 - val_loss: 0.3676 - val_accuracy: 0.8825
# Epoch 216/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.3512 - accuracy: 0.8825 - val_loss: 0.3657 - val_accuracy: 0.8825
# Epoch 217/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3493 - accuracy: 0.8869 - val_loss: 0.3636 - val_accuracy: 0.8825
# Epoch 218/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3473 - accuracy: 0.8831 - val_loss: 0.3618 - val_accuracy: 0.8850
# Epoch 219/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3454 - accuracy: 0.8844 - val_loss: 0.3601 - val_accuracy: 0.8900
# Epoch 220/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.3435 - accuracy: 0.8881 - val_loss: 0.3579 - val_accuracy: 0.8950
# Epoch 221/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.3415 - accuracy: 0.8888 - val_loss: 0.3558 - val_accuracy: 0.8950
# Epoch 222/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.3396 - accuracy: 0.8913 - val_loss: 0.3541 - val_accuracy: 0.8950
# Epoch 223/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.3378 - accuracy: 0.8900 - val_loss: 0.3522 - val_accuracy: 0.8950
# Epoch 224/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.3359 - accuracy: 0.8913 - val_loss: 0.3503 - val_accuracy: 0.8950
# Epoch 225/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3341 - accuracy: 0.8925 - val_loss: 0.3485 - val_accuracy: 0.8950
# Epoch 226/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.3322 - accuracy: 0.8919 - val_loss: 0.3465 - val_accuracy: 0.8950
# Epoch 227/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3304 - accuracy: 0.8931 - val_loss: 0.3447 - val_accuracy: 0.8975
# Epoch 228/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3286 - accuracy: 0.8963 - val_loss: 0.3429 - val_accuracy: 0.9000
# Epoch 229/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.3268 - accuracy: 0.8963 - val_loss: 0.3412 - val_accuracy: 0.9025
# Epoch 230/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3251 - accuracy: 0.9000 - val_loss: 0.3395 - val_accuracy: 0.9025
# Epoch 231/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.3233 - accuracy: 0.8988 - val_loss: 0.3377 - val_accuracy: 0.9025
# Epoch 232/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3216 - accuracy: 0.9006 - val_loss: 0.3361 - val_accuracy: 0.9025
# Epoch 233/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3199 - accuracy: 0.8994 - val_loss: 0.3343 - val_accuracy: 0.9025
# Epoch 234/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.3183 - accuracy: 0.9013 - val_loss: 0.3326 - val_accuracy: 0.9025
# Epoch 235/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.3166 - accuracy: 0.9019 - val_loss: 0.3309 - val_accuracy: 0.9025
# Epoch 236/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3149 - accuracy: 0.9025 - val_loss: 0.3292 - val_accuracy: 0.9050
# Epoch 237/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3133 - accuracy: 0.9013 - val_loss: 0.3274 - val_accuracy: 0.9050
# Epoch 238/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3117 - accuracy: 0.9025 - val_loss: 0.3258 - val_accuracy: 0.9075
# Epoch 239/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.3101 - accuracy: 0.9044 - val_loss: 0.3240 - val_accuracy: 0.9050
# Epoch 240/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.3085 - accuracy: 0.9031 - val_loss: 0.3226 - val_accuracy: 0.9050
# Epoch 241/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.3069 - accuracy: 0.9031 - val_loss: 0.3210 - val_accuracy: 0.9075
# Epoch 242/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.3053 - accuracy: 0.9062 - val_loss: 0.3192 - val_accuracy: 0.9075
# Epoch 243/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3038 - accuracy: 0.9044 - val_loss: 0.3176 - val_accuracy: 0.9050
# Epoch 244/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3023 - accuracy: 0.9050 - val_loss: 0.3162 - val_accuracy: 0.9075
# Epoch 245/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.3007 - accuracy: 0.9056 - val_loss: 0.3143 - val_accuracy: 0.9075
# Epoch 246/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2993 - accuracy: 0.9044 - val_loss: 0.3128 - val_accuracy: 0.9100
# Epoch 247/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2978 - accuracy: 0.9050 - val_loss: 0.3113 - val_accuracy: 0.9075
# Epoch 248/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2963 - accuracy: 0.9056 - val_loss: 0.3098 - val_accuracy: 0.9075
# Epoch 249/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2948 - accuracy: 0.9050 - val_loss: 0.3084 - val_accuracy: 0.9075
# Epoch 250/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2934 - accuracy: 0.9050 - val_loss: 0.3068 - val_accuracy: 0.9075
# Epoch 251/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2919 - accuracy: 0.9050 - val_loss: 0.3054 - val_accuracy: 0.9075
# Epoch 252/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2904 - accuracy: 0.9056 - val_loss: 0.3040 - val_accuracy: 0.9075
# Epoch 253/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2891 - accuracy: 0.9069 - val_loss: 0.3024 - val_accuracy: 0.9075
# Epoch 254/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2877 - accuracy: 0.9069 - val_loss: 0.3009 - val_accuracy: 0.9075
# Epoch 255/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2863 - accuracy: 0.9062 - val_loss: 0.2995 - val_accuracy: 0.9075
# Epoch 256/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2849 - accuracy: 0.9075 - val_loss: 0.2979 - val_accuracy: 0.9075
# Epoch 257/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2835 - accuracy: 0.9075 - val_loss: 0.2964 - val_accuracy: 0.9100
# Epoch 258/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2822 - accuracy: 0.9081 - val_loss: 0.2951 - val_accuracy: 0.9075
# Epoch 259/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2808 - accuracy: 0.9087 - val_loss: 0.2940 - val_accuracy: 0.9075
# Epoch 260/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2796 - accuracy: 0.9075 - val_loss: 0.2926 - val_accuracy: 0.9100
# Epoch 261/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2783 - accuracy: 0.9081 - val_loss: 0.2913 - val_accuracy: 0.9100
# Epoch 262/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2770 - accuracy: 0.9081 - val_loss: 0.2899 - val_accuracy: 0.9100
# Epoch 263/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2757 - accuracy: 0.9087 - val_loss: 0.2885 - val_accuracy: 0.9175
# Epoch 264/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2745 - accuracy: 0.9100 - val_loss: 0.2872 - val_accuracy: 0.9150
# Epoch 265/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2731 - accuracy: 0.9125 - val_loss: 0.2859 - val_accuracy: 0.9150
# Epoch 266/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2720 - accuracy: 0.9100 - val_loss: 0.2845 - val_accuracy: 0.9150
# Epoch 267/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2707 - accuracy: 0.9106 - val_loss: 0.2833 - val_accuracy: 0.9150
# Epoch 268/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2694 - accuracy: 0.9125 - val_loss: 0.2821 - val_accuracy: 0.9150
# Epoch 269/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2682 - accuracy: 0.9112 - val_loss: 0.2810 - val_accuracy: 0.9150
# Epoch 270/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2670 - accuracy: 0.9125 - val_loss: 0.2797 - val_accuracy: 0.9150
# Epoch 271/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2659 - accuracy: 0.9137 - val_loss: 0.2786 - val_accuracy: 0.9150
# Epoch 272/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2647 - accuracy: 0.9137 - val_loss: 0.2772 - val_accuracy: 0.9150
# Epoch 273/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2635 - accuracy: 0.9137 - val_loss: 0.2759 - val_accuracy: 0.9200
# Epoch 274/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2624 - accuracy: 0.9137 - val_loss: 0.2747 - val_accuracy: 0.9225
# Epoch 275/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2612 - accuracy: 0.9156 - val_loss: 0.2735 - val_accuracy: 0.9200
# Epoch 276/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2601 - accuracy: 0.9162 - val_loss: 0.2723 - val_accuracy: 0.9225
# Epoch 277/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2590 - accuracy: 0.9162 - val_loss: 0.2712 - val_accuracy: 0.9225
# Epoch 278/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2579 - accuracy: 0.9162 - val_loss: 0.2699 - val_accuracy: 0.9225
# Epoch 279/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2568 - accuracy: 0.9162 - val_loss: 0.2688 - val_accuracy: 0.9250
# Epoch 280/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2557 - accuracy: 0.9175 - val_loss: 0.2677 - val_accuracy: 0.9225
# Epoch 281/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2546 - accuracy: 0.9194 - val_loss: 0.2666 - val_accuracy: 0.9225
# Epoch 282/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2536 - accuracy: 0.9181 - val_loss: 0.2654 - val_accuracy: 0.9250
# Epoch 283/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2525 - accuracy: 0.9194 - val_loss: 0.2642 - val_accuracy: 0.9300
# Epoch 284/500
# 100/100 [==============================] - 0s 5ms/step - loss: 0.
500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2186 - accuracy: 0.9312 - val_loss: 0.2273 - val_accuracy: 0.9375
# Epoch 320/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2178 - accuracy: 0.9300 - val_loss: 0.2267 - val_accuracy: 0.9375
# Epoch 321/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2170 - accuracy: 0.9275 - val_loss: 0.2257 - val_accuracy: 0.9375
# Epoch 322/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2162 - accuracy: 0.9300 - val_loss: 0.2247 - val_accuracy: 0.9375
# Epoch 323/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2155 - accuracy: 0.9306 - val_loss: 0.2239 - val_accuracy: 0.9375
# Epoch 324/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2146 - accuracy: 0.9319 - val_loss: 0.2231 - val_accuracy: 0.9375
# Epoch 325/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2139 - accuracy: 0.9319 - val_loss: 0.2221 - val_accuracy: 0.9375
# Epoch 326/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2131 - accuracy: 0.9325 - val_loss: 0.2213 - val_accuracy: 0.9375
# Epoch 327/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2123 - accuracy: 0.9325 - val_loss: 0.2205 - val_accuracy: 0.9375
# Epoch 328/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2116 - accuracy: 0.9325 - val_loss: 0.2195 - val_accuracy: 0.9375
# Epoch 329/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2108 - accuracy: 0.9331 - val_loss: 0.2187 - val_accuracy: 0.9375
# Epoch 330/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2100 - accuracy: 0.9331 - val_loss: 0.2178 - val_accuracy: 0.9375
# Epoch 331/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2093 - accuracy: 0.9325 - val_loss: 0.2171 - val_accuracy: 0.9375
# Epoch 332/500
# ...
# Epoch 391/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1731 - accuracy: 0.9469 - val_loss: 0.1769 - val_accuracy: 0.9575
# Epoch 392/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1726 - accuracy: 0.9481 - val_loss: 0.1763 - val_accuracy: 0.9575
# Epoch 393/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1721 - accuracy: 0.9488 - val_loss: 0.1758 - val_accuracy: 0.9575
# Epoch 394/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1717 - accuracy: 0.9488 - val_loss: 0.1752 - val_accuracy: 0.9575
# Epoch 395/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1712 - accuracy: 0.9506 - val_loss: 0.1746 - val_accuracy: 0.9575
# Epoch 396/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1707 - accuracy: 0.9481 - val_loss: 0.1743 - val_accuracy: 0.9600
# Epoch 397/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1703 - accuracy: 0.9488 - val_loss: 0.1737 - val_accuracy: 0.9600
# Epoch 398/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1697 - accuracy: 0.9506 - val_loss: 0.1733 - val_accuracy: 0.9575
# Epoch 399/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1692 - accuracy: 0.9488 - val_loss: 0.1727 - val_accuracy: 0.9600
# Epoch 400/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1688 - accuracy: 0.9500 - val_loss: 0.1723 - val_accuracy: 0.9600
# Epoch 401/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1684 - accuracy: 0.9488 - val_loss: 0.1718 - val_accuracy: 0.9600
# Epoch 402/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1679 - accuracy: 0.9513 - val_loss: 0.1712 - val_accuracy: 0.9625
# Epoch 403/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1674 - accuracy: 0.9494 - val_loss: 0.1707 - val_accuracy: 0.9625
# Epoch 404/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1670 - accuracy: 0.9506 - val_loss: 0.1702 - val_accuracy: 0.9625
# Epoch 405/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1666 - accuracy: 0.9494 - val_loss: 0.1698 - val_accuracy: 0.9650
# Epoch 406/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1661 - accuracy: 0.9525 - val_loss: 0.1695 - val_accuracy: 0.9625
# Epoch 407/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1657 - accuracy: 0.9519 - val_loss: 0.1689 - val_accuracy: 0.9650
# Epoch 408/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1652 - accuracy: 0.9538 - val_loss: 0.1684 - val_accuracy: 0.9650
# Epoch 409/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1648 - accuracy: 0.9531 - val_loss: 0.1679 - val_accuracy: 0.9650
# Epoch 410/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1643 - accuracy: 0.9525 - val_loss: 0.1674 - val_accuracy: 0.9650
# Epoch 411/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1639 - accuracy: 0.9531 - val_loss: 0.1670 - val_accuracy: 0.9650
# Epoch 412/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1635 - accuracy: 0.9500 - val_loss: 0.1665 - val_accuracy: 0.9650
# Epoch 413/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1630 - accuracy: 0.9538 - val_loss: 0.1660 - val_accuracy: 0.9650
# Epoch 414/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1626 - accuracy: 0.9513 - val_loss: 0.1657 - val_accuracy: 0.9650
# Epoch 415/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1621 - accuracy: 0.9531 - val_loss: 0.1653 - val_accuracy: 0.9625
# Epoch 416/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1617 - accuracy: 0.9531 - val_loss: 0.1647 - val_accuracy: 0.9625
# Epoch 417/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1613 - accuracy: 0.9519 - val_loss: 0.1642 - val_accuracy: 0.9625
# Epoch 418/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1609 - accuracy: 0.9513 - val_loss: 0.1638 - val_accuracy: 0.9625
# Epoch 419/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1605 - accuracy: 0.9525 - val_loss: 0.1634 - val_accuracy: 0.9625
# Epoch 420/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1600 - accuracy: 0.9513 - val_loss: 0.1630 - val_accuracy: 0.9625
# Epoch 421/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1596 - accuracy: 0.9538 - val_loss: 0.1624 - val_accuracy: 0.9625
# Epoch 422/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1592 - accuracy: 0.9538 - val_loss: 0.1619 - val_accuracy: 0.9625
# Epoch 423/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1588 - accuracy: 0.9531 - val_loss: 0.1614 - val_accuracy: 0.9625
# Epoch 424/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1584 - accuracy: 0.9525 - val_loss: 0.1611 - val_accuracy: 0.9625
# Epoch 425/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1580 - accuracy: 0.9525 - val_loss: 0.1606 - val_accuracy: 0.9625
# Epoch 426/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1575 - accuracy: 0.9519 - val_loss: 0.1602 - val_accuracy: 0.9625
# Epoch 427/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1571 - accuracy: 0.9538 - val_loss: 0.1597 - val_accuracy: 0.9650
# Epoch 428/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1567 - accuracy: 0.9538 - val_loss: 0.1592 - val_accuracy: 0.9650
# Epoch 429/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1563 - accuracy: 0.9544 - val_loss: 0.1588 - val_accuracy: 0.9650
# Epoch 430/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1559 - accuracy: 0.9538 - val_loss: 0.1583 - val_accuracy: 0.9650
# Epoch 431/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1555 - accuracy: 0.9544 - val_loss: 0.1578 - val_accuracy: 0.9650
# Epoch 432/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1551 - accuracy: 0.9544 - val_loss: 0.1575 - val_accuracy: 0.9625
# Epoch 433/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1548 - accuracy: 0.9544 - val_loss: 0.1570 - val_accuracy: 0.9625
# Epoch 434/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1543 - accuracy: 0.9550 - val_loss: 0.1566 - val_accuracy: 0.9650
# Epoch 435/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1540 - accuracy: 0.9544 - val_loss: 0.1562 - val_accuracy: 0.9650
# Epoch 436/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1535 - accuracy: 0.9525 - val_loss: 0.1557 - val_accuracy: 0.9650
# Epoch 437/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1532 - accuracy: 0.9538 - val_loss: 0.1553 - val_accuracy: 0.9650
# Epoch 438/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1528 - accuracy: 0.9550 - val_loss: 0.1548 - val_accuracy: 0.9650
# Epoch 439/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1524 - accuracy: 0.9544 - val_loss: 0.1544 - val_accuracy: 0.9650
# Epoch 440/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1520 - accuracy: 0.9550 - val_loss: 0.1540 - val_accuracy: 0.9650
# Epoch 441/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1516 - accuracy: 0.9538 - val_loss: 0.1536 - val_accuracy: 0.9675
# Epoch 442/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1513 - accuracy: 0.9556 - val_loss: 0.1531 - val_accuracy: 0.9650
# Epoch 443/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1509 - accuracy: 0.9556 - val_loss: 0.1527 - val_accuracy: 0.9650
# Epoch 444/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1505 - accuracy: 0.9556 - val_loss: 0.1522 - val_accuracy: 0.9650
# Epoch 445/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1501 - accuracy: 0.9563 - val_loss: 0.1519 - val_accuracy: 0.9650
# Epoch 446/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1497 - accuracy: 0.9550 - val_loss: 0.1516 - val_accuracy: 0.9675
# Epoch 447/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1494 - accuracy: 0.9563 - val_loss: 0.1513 - val_accuracy: 0.9675
# Epoch 448/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1490 - accuracy: 0.9550 - val_loss: 0.1509 - val_accuracy: 0.9675
# Epoch 449/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1487 - accuracy: 0.9563 - val_loss: 0.1504 - val_accuracy: 0.9675
# Epoch 450/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1482 - accuracy: 0.9563 - val_loss: 0.1499 - val_accuracy: 0.9675
# Epoch 451/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1479 - accuracy: 0.9563 - val_loss: 0.1494 - val_accuracy: 0.9675
# Epoch 452/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1476 - accuracy: 0.9569 - val_loss: 0.1491 - val_accuracy: 0.9675
# Epoch 453/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1472 - accuracy: 0.9550 - val_loss: 0.1487 - val_accuracy: 0.9675
# Epoch 454/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1468 - accuracy: 0.9575 - val_loss: 0.1483 - val_accuracy: 0.9675
# Epoch 455/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1464 - accuracy: 0.9569 - val_loss: 0.1480 - val_accuracy: 0.9675
# Epoch 456/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1461 - accuracy: 0.9563 - val_loss: 0.1476 - val_accuracy: 0.9675
# Epoch 457/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1457 - accuracy: 0.9563 - val_loss: 0.1473 - val_accuracy: 0.9650
# Epoch 458/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1454 - accuracy: 0.9575 - val_loss: 0.1468 - val_accuracy: 0.9675
# Epoch 459/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1450 - accuracy: 0.9581 - val_loss: 0.1464 - val_accuracy: 0.9675
# Epoch 460/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1447 - accuracy: 0.9575 - val_loss: 0.1460 - val_accuracy: 0.9675
# Epoch 461/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1442 - accuracy: 0.9575 - val_loss: 0.1456 - val_accuracy: 0.9675
# Epoch 462/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1439 - accuracy: 0.9575 - val_loss: 0.1452 - val_accuracy: 0.9675
# Epoch 463/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1436 - accuracy: 0.9581 - val_loss: 0.1447 - val_accuracy: 0.9675
# Epoch 464/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1432 - accuracy: 0.9575 - val_loss: 0.1443 - val_accuracy: 0.9675
# Epoch 465/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1429 - accuracy: 0.9569 - val_loss: 0.1441 - val_accuracy: 0.9675
# Epoch 466/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1425 - accuracy: 0.9581 - val_loss: 0.1437 - val_accuracy: 0.9675
# Epoch 467/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1422 - accuracy: 0.9569 - val_loss: 0.1433 - val_accuracy: 0.9675
# Epoch 468/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1418 - accuracy: 0.9581 - val_loss: 0.1428 - val_accuracy: 0.9675
# Epoch 469/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1414 - accuracy: 0.9594 - val_loss: 0.1427 - val_accuracy: 0.9675
# Epoch 470/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1411 - accuracy: 0.9581 - val_loss: 0.1423 - val_accuracy: 0.9650
# Epoch 471/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1408 - accuracy: 0.9581 - val_loss: 0.1419 - val_accuracy: 0.9650
# Epoch 472/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1404 - accuracy: 0.9575 - val_loss: 0.1413 - val_accuracy: 0.9700
# Epoch 473/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1401 - accuracy: 0.9575 - val_loss: 0.1409 - val_accuracy: 0.9725
# Epoch 474/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1398 - accuracy: 0.9594 - val_loss: 0.1405 - val_accuracy: 0.9700
# Epoch 475/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1394 - accuracy: 0.9606 - val_loss: 0.1402 - val_accuracy: 0.9700
# Epoch 476/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1391 - accuracy: 0.9600 - val_loss: 0.1400 - val_accuracy: 0.9700
# Epoch 477/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1388 - accuracy: 0.9575 - val_loss: 0.1396 - val_accuracy: 0.9700
# Epoch 478/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1385 - accuracy: 0.9575 - val_loss: 0.1392 - val_accuracy: 0.9700
# Epoch 479/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1381 - accuracy: 0.9588 - val_loss: 0.1388 - val_accuracy: 0.9700
# Epoch 480/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1378 - accuracy: 0.9600 - val_loss: 0.1384 - val_accuracy: 0.9700
# Epoch 481/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1374 - accuracy: 0.9581 - val_loss: 0.1380 - val_accuracy: 0.9725
# Epoch 482/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1371 - accuracy: 0.9613 - val_loss: 0.1377 - val_accuracy: 0.9725
# Epoch 483/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1369 - accuracy: 0.9594 - val_loss: 0.1374 - val_accuracy: 0.9725
# Epoch 484/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1365 - accuracy: 0.9606 - val_loss: 0.1370 - val_accuracy: 0.9725
# Epoch 485/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1362 - accuracy: 0.9594 - val_loss: 0.1366 - val_accuracy: 0.9725
# Epoch 486/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1359 - accuracy: 0.9619 - val_loss: 0.1364 - val_accuracy: 0.9725
# Epoch 487/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1355 - accuracy: 0.9606 - val_loss: 0.1361 - val_accuracy: 0.9750
# Epoch 488/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1351 - accuracy: 0.9613 - val_loss: 0.1356 - val_accuracy: 0.9750
# Epoch 489/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1349 - accuracy: 0.9606 - val_loss: 0.1353 - val_accuracy: 0.9750
# Epoch 490/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1345 - accuracy: 0.9613 - val_loss: 0.1349 - val_accuracy: 0.9750
# Epoch 491/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1342 - accuracy: 0.9625 - val_loss: 0.1346 - val_accuracy: 0.9750
# Epoch 492/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1339 - accuracy: 0.9619 - val_loss: 0.1343 - val_accuracy: 0.9750
# Epoch 493/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1336 - accuracy: 0.9638 - val_loss: 0.1339 - val_accuracy: 0.9750
# Epoch 494/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1333 - accuracy: 0.9638 - val_loss: 0.1336 - val_accuracy: 0.9725
# Epoch 495/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1330 - accuracy: 0.9619 - val_loss: 0.1333 - val_accuracy: 0.9725
# Epoch 496/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1326 - accuracy: 0.9631 - val_loss: 0.1329 - val_accuracy: 0.9750
# Epoch 497/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1323 - accuracy: 0.9625 - val_loss: 0.1325 - val_accuracy: 0.9750
# Epoch 498/500
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1320 - accuracy: 0.9606 - val_loss: 0.1322 - val_accuracy: 0.9750
# Epoch 499/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1317 - accuracy: 0.9625 - val_loss: 0.1319 - val_accuracy: 0.9750
# Epoch 500/500
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1314 - accuracy: 0.9644 - val_loss: 0.1316 - val_accuracy: 0.9750

# %% [markdown]
# Plotting the loss and accuracy of the model that has been made.

# %%
plt.figure(figsize=(10,4))
plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.grid(True)
plt.show()

plt.figure(figsize=(10,4))
plt.plot(history.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.grid(True)
plt.show()

# %% [markdown]
# Calling the dataset to test. Because in this dataset the test data and training data are separated.

# %%
df_test = pd.read_csv("/content/drive/MyDrive/Kaggle/test_Mobile Price Classification.csv")
df_test.head()
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# 1    0.8        191  ...  12        746       857  3895     6     0
# 2    0.9        186  ...   4       1270      1366  2396    17    10
# 3    0.5         96  ...  20        295      1752  3893    10     0
# 4    0.5        108  ...  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# 1          7        1             0     0
# 2         10        0             1     1
# 3          7        1             1     0
# 4          7        1             0     1
#
# [5 rows x 21 columns]

# %% [markdown]
# Removed the id column as it is not being used

# %%
df_test = df_test.drop('id', axis=1)

# %% [markdown]
# Because this dataset uses scaling data, the new dataset must be scaled first.

# %%
tf = StandardScaler().fit_transform(df_test)
df_test_scale = pd.DataFrame(tf, columns=X.columns)

# %% [markdown]
# Displays test data that has been scaled

# %%
df_test_scale
# Out:
#      battery_power      blue  clock_speed  dual_sim        fc    four_g  \
# 0        -0.475451  0.968496     0.312601  0.966559  2.108676 -0.974329
# 1        -0.942782  0.968496    -1.255832  0.966559 -0.132927  1.026347
# 2         1.292077  0.968496     1.519087 -1.034598 -0.805408 -0.974329
# 3         0.688249 -1.032529    -1.255832  0.966559  3.005317  1.026347
# 4         0.429135 -1.032529    -0.169994 -1.034598  1.436195  1.026347
# ..             ...       ...          ...       ...       ...       ...
# 995       1.044531  0.968496     0.433249 -1.034598 -1.029568  1.026347
# 996      -1.479519 -1.032529     0.312601  0.966559 -1.029568 -0.974329
# 997      -0.146932 -1.032529    -0.169994 -1.034598 -0.805408  1.026347
# 998       0.658173  0.968496    -1.255832  0.966559 -1.029568 -0.974329
# 999       0.049718  0.968496    -1.255832 -1.034598 -0.132927  1.026347
#
#      int_memory     m_dep  mobile_wt   n_cores        pc  px_height  px_width  \
# 0     -1.581269 -1.487247   1.535535 -0.580671  0.976026  -0.926990  0.391912
# 1      1.509303  1.006341   1.478120  0.293833  0.319433   0.274729 -0.871028
# 2     -0.367116  1.362567   1.334582 -0.580671 -0.993754   1.485693  0.287236
# 3     -0.477493 -0.062340  -1.249091  1.605590  1.632619  -0.767532  1.165604
# 4      0.847037 -0.062340  -0.904602  0.731085  1.304323   0.281662 -0.977979
# ..          ...       ...        ...       ...       ...        ...       ...
# 995    1.122981 -0.062340   0.875263  1.168338  1.140174   0.039007 -0.743596
# 996   -1.139759  1.362567   1.334582 -0.143419 -1.322051   1.212995  0.892536
# 997   -1.415702 -0.062340  -1.708411 -1.455175  0.319433  -0.346930 -0.943846
# 998    0.902226 -0.418566   0.903970 -1.017923  0.319433  -1.361458 -0.927917
# 999    0.074394 -1.487247   0.014038  0.731085  1.468471  -0.393150 -1.437643
#
#           ram      sc_h      sc_w  talk_time   three_g  touch_screen      wifi
# 0    1.229373  0.001158  0.397363  -1.653355 -1.760216           1.0 -1.014099
# 1    1.614643 -1.388231 -1.254383  -0.743418  0.568112          -1.0 -1.014099
# 2    0.236313  1.158982  1.105254  -0.197456 -1.760216           1.0  0.986097
# 3    1.612804 -0.461972 -1.254383  -0.743418  0.568112           1.0 -1.014099
# 4   -0.336535  0.695852  0.633326  -0.743418  0.568112          -1.0  0.986097
# ..        ...       ...       ...        ...       ...           ...       ...
# 995 -0.016549  0.464287  0.633326   0.712481  0.568112           1.0 -1.014099
# 996 -0.189415 -0.925101 -1.018419   1.440430 -1.760216           1.0  0.986097
# 997 -0.842260 -1.619796 -1.254383   0.530493  0.568112          -1.0 -1.014099
# 998  0.340217  0.695852  1.341217  -0.925406 -1.760216           1.0 -1.014099
# 999  0.633537 -0.693537 -0.782455  -1.471368  0.568112          -1.0  0.986097
#
# [1000 rows x 20 columns]

# %% [markdown]
# Make a program to see the prediction results using "X_test"

# %%
x = 0
y = 1
hasil_prediksi = []
for i in range(80):
  prediksi = model.predict(X_test[x:y])
  kelas = np.argmax(prediksi)
  hasil_prediksi.append(kelas)
  x+=1
  y+=1
print(hasil_prediksi)
ypred = np.array(hasil_prediksi)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# [0, 2, 1, 3, 1, 1, 1, 0, 2, 1, 0, 1, 2, 3, 3, 2, 3, 3, 1, 0, 0, 2, 1, 2, 0, 1, 3, 2, 2, 0, 0, 0, 3, 0, 1, 1, 2, 0, 3, 0, 2, 3, 2, 0, 3, 3, 2, 1, 3, 1, 3, 1, 0, 0, 0, 0, 1, 3, 0, 0, 1, 3, 3, 1, 0, 0, 3, 3, 1, 2, 2, 2, 0, 1, 2, 0, 0, 3, 2, 2]

# %% [markdown]
# Kemudian melihat Confusion matrix hasil dari model tersebut yang disimpan pada variabel ypred dan dibandingkan dengan variabel y_test. Dapat dilihat f1 score yang didapatkan dari model ini adalah 93%.

# %%
conf_matrix = confusion_matrix(y_true=y_test[0:80], y_pred=ypred)
fig, ax = plt.subplots(figsize=(7.5, 7.5))
ax.matshow(conf_matrix, cmap=plt.cm.Blues, alpha=0.3)
for i in range(conf_matrix.shape[0]):
  for j in range(conf_matrix.shape[1]):
    ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size='xx-large')
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()
report = classification_report(ypred, y_test[0:80])
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94        24
#            1       0.89      0.89      0.89        19
#            2       0.89      0.94      0.92        18
#            3       0.95      0.95      0.95        19
#
#     accuracy                           0.93        80
#    macro avg       0.92      0.93      0.92        80
# weighted avg       0.93      0.93      0.93        80

# %% [markdown]
# After that, we try to plot the test data or y-test using the dot plot with the aim that later it will be compared with the plotted data of the predicted results

# %%
y_test_array = np.array(y_test[0:40])
plt.plot(y_test_array, 'ro')
plt.show()

# %% [markdown]
# Plot prediction results

# %%
plt.plot(ypred, 'go')
plt.show()

# %% [markdown]
# It can be seen the comparison of plotting on the test data and training data. Only a few data differ between test data and training data.

# %%
plt.plot(ypred, 'go')
plt.plot(y_test_array, 'ro')
plt.show()

# %% [markdown]
# Classification results using dt_test_scale

# %%
x = 0
y = 1
hasil_prediksi = []
for i in range(20):
  prediksi = model.predict(df_test_scale[x:y])
  kelas = np.argmax(prediksi)
  hasil_prediksi.append(kelas)
  x+=1
  y+=1
print(hasil_prediksi)
ypred = np.array(hasil_prediksi)
# Out:
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# [3, 3, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 0, 0, 2, 0, 2, 1, 3, 2]
